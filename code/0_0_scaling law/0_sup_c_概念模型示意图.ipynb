# %%
########################## 这个是最终的结果，之前的相关性写错了 ##############
#关于文档的一个数据分类
import pandas as pd
import seaborn as sns  #用于绘制热图的工具包
from scipy.cluster import hierarchy  #用于进行层次聚类，话层次聚类图的工具包
from scipy import cluster   
import matplotlib.pyplot as plt
from sklearn import decomposition as skldec #用于主成分分析降维的包
import numpy as np
#import csv
import math
from pandas import Series,DataFrame
from matplotlib.ticker import  MultipleLocator
import pylab as pl   #画图用
from sklearn import svm
from sklearn import linear_model

# %%
x1 = [1,3]
y1=[1,3]
x2 = [6/5,4]
y2=[9/10,3]
x3 = [3/2,4]
y3=[5/2,20/3]

x11 = [4/3,5/2]
x21 = [2,7/2]
y21 = [3/2,21/8]
x31 = [1,7/2]
y31= [5/3,35/6]
plt.scatter(x11,x11,color = 'red')
plt.scatter(x21,y21,color = 'red')
plt.plot(x1,y1,'black')
# plt.plot(x2,x2)
plt.plot(x2,y2,)
plt.axvline(x=3/2, c="orange", ls="--", lw=2,alpha=0.5)
plt.axvline(x=5/2, c="orange", ls="--", lw=2,alpha=0.5)
plt.axvline(x=2, c="orange",  lw=2,alpha=0.5)
plt.axvline(x=7/2, c="orange",  lw=2,alpha=0.5)
# plt.plot(x2,x2,'--')
# plt.xticks([])  #去掉横坐标值
# plt.yticks([])  #去掉纵坐标值

# %%
plt.figure(figsize=(6.5,6))
plt.scatter(x11,x11,color = 'red')
plt.scatter(x21,y21,color = 'red')
plt.plot(x1,y1,'black')
# plt.plot(x2,x2)
plt.plot(x2,y2)
plt.scatter(x11,[1,15/8],marker='d',s=100,alpha=0.45)
plt.plot([4/3,2],[1,1],'--',color='orange')
plt.plot([2,2],[1,3/2],color='g')
plt.plot([5/2,7/2],[15/8,15/8],'--',color='orange')
plt.plot([7/2,7/2],[15/8,21/8],color='g')

plt.plot([4/3,4/3],[1,4/3],'--',color='orange')
plt.plot([5/2,5/2],[15/8,5/2],'--',color='orange')
plt.xticks([])  #去掉横坐标值
plt.yticks([])  #去掉纵坐标值
plt.text(2.1,1.2,'$\Delta {}$'.format('y_s'),size=16)
plt.text(3.6,2.2,'$\Delta {}$'.format('y_b'),size=16)
# Out:
# Text(3.6,2.2,'$\\Delta y_b$')
